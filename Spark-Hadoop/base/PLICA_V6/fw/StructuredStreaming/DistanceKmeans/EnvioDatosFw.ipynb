# %%
#Este es el script en el que se maneja el envio de eventos kafka
#Se crea un producer de kafka y se obtienen datos para enviar

"""
FUNCIONAL
"""
# kafka/bin/zookeeper-server-start.sh kafka/config/zookeeper.properties
# kafka/bin/kafka-server-start.sh kafka/config/server.properties
# kafka/bin/kafka-topics.sh --create --zookeeper localhost:2181 --replication-factor 1 --partitions 1 --topic FW
# kafka/bin/kafka-topics.sh --create --zookeeper 138.4.7.158:2181 --replication-factor 1 --partitions 1 --topic FW

# kafka/bin/kafka-topics.sh --delete --zookeeper localhost:2181 --topic FW
 
# kafka/bin/kafka-topics.sh --list --zookeeper localhost:2181
# kafka/bin/kafka-topics.sh --list --zookeeper 138.4.7.158:2181
# kafka/bin/kafka-console-consumer.sh --bootstrap-server 192.168.1.101:9092 --topic FW --from-beginning

# ./elasticsearch/bin/elasticsearch
# ./kibana/bin/kibana
# curl -XDELETE 'http://localhost:9200/fw*'

import findspark
findspark.init()

import time

from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

from kafka import KafkaProducer, TopicPartition
import uuid

# %%
#Se crea una sescion de spark
#Importante tras ejecucion hacer sc.stop()

sc = SparkContext('local')
spark = SparkSession(sc)

# %%
base_path='../../'

# %%
#Se define el esquema que va a tener el data frame

schema = StructType([
    StructField('Time', StringType(), True),
    StructField('Blade', StringType(), True),
    StructField('Action', StringType(), True),
    StructField('Type', StringType(), True),
    StructField('Interface', StringType(), True),
    StructField('Origin', StringType(), True),
    StructField('Source', StringType(), True),
    StructField('Source User Name', StringType(), True),
    StructField('Destination', StringType(), True),
    StructField('Service', StringType(), True),
    StructField('Access Rule Number', StringType(), True),
    StructField('Access Rule Name', StringType(), True),
    StructField('Policy Name', StringType(), True),
    StructField('Description', StringType(), True),
    StructField('Id', StringType(), True),
    StructField('Marker', StringType(), True),
    StructField('Log Server Origin', StringType(), True),
    StructField('Interface Direction', StringType(), True),
    StructField('Interface Name', StringType(), True),
    StructField('Connection Direction', StringType(), True),
    StructField('Id Generated By Indexer', StringType(), True),
    StructField('First', StringType(), True),
    StructField('Sequencenum', StringType(), True),
    StructField('Source Zone', StringType(), True),
    StructField('Destination Zone', StringType(), True),
    StructField('Service ID', StringType(), True),
    StructField('Source Port', StringType(), True),
    StructField('Destination Port', StringType(), True),
    StructField('IP Protocol', StringType(), True),
    StructField('Xlate (NAT) Source IP', StringType(), True),
    StructField('Xlate (NAT) Source Port', StringType(), True),
    StructField('Xlate (NAT) Destination Port', StringType(), True),
    StructField('NAT Rule Number', StringType(), True),
    StructField('NAT Additional Rule Number', StringType(), True),
    StructField('Source Machine Name', StringType(), True),
    StructField('Hll Key', StringType(), True),
    StructField('Context Num', StringType(), True),
    StructField('Policy Management', StringType(), True),
    StructField('Db Tag', StringType(), True),
    StructField('Policy Date', StringType(), True),
    StructField('Product Family', StringType(), True),
    StructField('Logid', StringType(), True),
    StructField('Policy Rule UID', StringType(), True),
    StructField('Layer Name', StringType(), True),
    StructField('Needs Browse Time', StringType(), True),
    StructField('User', StringType(), True),
    StructField('Src User Dn', StringType(), True),
    StructField('Protocol', StringType(), True),
    StructField('Sig Id', StringType(), True),
    StructField('Reason', StringType(), True),
    StructField('Destination Machine Name', StringType(), True),
    StructField('Destination User Name', StringType(), True),
    StructField('Dst User Dn', StringType(), True),
    StructField('UserCheck ID', StringType(), True),
    StructField('Destination Object', StringType(), True),
    StructField('ICMP', StringType(), True),
    StructField('ICMP Type', StringType(), True),
    StructField('ICMP Code', StringType(), True),
    StructField('Client Name', StringType(), True),
    StructField('Product Version', StringType(), True),
    StructField('Domain Name', StringType(), True),
    StructField('Endpoint IP', StringType(), True),
    StructField('Authentication Status', StringType(), True),
    StructField('Identity Source', StringType(), True),
    StructField('Session ID', StringType(), True),
    StructField('Source Machine Group', StringType(), True),
    StructField('Authentication Method', StringType(), True),
    StructField('Identity Type', StringType(), True),
    StructField('Authentication Trial', StringType(), True),
    StructField('Source User Group', StringType(), True),
    StructField('Connection Id', StringType(), True),
    StructField('Last Update Time71', StringType(), True),
    StructField('Scheme', StringType(), True),
    StructField('Methods', StringType(), True),
    StructField('VPN Peer Gateway', StringType(), True),
    StructField('Community', StringType(), True),
    StructField('Mobile Access Session UID', StringType(), True),
    StructField('VPN Feature', StringType(), True),
    StructField('Duration', StringType(), True),
    StructField('Last Update Time79', StringType(), True),
    StructField('Update Count', StringType(), True),
    StructField('Creation Time', StringType(), True),
    StructField('Connections', StringType(), True),
    StructField('Aggregated Log Count', StringType(), True),
    StructField('_c84', StringType(), True)
])

# %%
df = spark.read.schema(schema).load(f'{base_path}datasets/dataset_fw_v1.csv',
                     format="csv", sep=",", inferSchema="false", header="true")

# %%
# Añadimos metadatos para simular eventos del sensor

df = df.withColumn('data', struct(col('*')))
df = df.withColumn('version', lit('1.0'))
df = df.withColumn('id' , lit('f0c48ba4-387d-11ea-a137-2e728ce88126'))
df = df.withColumn('type', lit('FW'))
df = df.withColumn('event', lit('DATA'))

# %%
# Creamos productor de eventos Kafka

ip_server = '192.168.1.101:9092'
kafka_topic = 'FW'
c = 0
sleep = 20
seed = 1

while True:
    df_sample = df.sample(fraction = 0.1, seed = seed)
    df_sample = df_sample.withColumn('time', unix_timestamp().cast(StringType()))
    
    prediction_features = df_sample.select('version','time','id','type','event','data')

    if type(kafka_topic) == bytes:
        kafka_topic = kafka_topic.decode('utf-8')
    producer = KafkaProducer(bootstrap_servers=[ip_server],api_version=(0,10))
    PREDICTION_TOPIC = kafka_topic

    #FUNCIONAL
    for row in prediction_features.toJSON().collect():
        print((row))
        producer.send(PREDICTION_TOPIC , row.encode())
        producer.flush()
    
    time.sleep(sleep)
    c = c + 1
    seed = seed + 1
# Out:
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:46 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"srv2.telconet.net (200.93.192.161)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 200.93.192.161","Id":"5b83a05e-a69f-e3fc-5ece-93d600010005","Marker":"@A@@B@1590555605@C@2969330","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"50","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"64159","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"54880","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"9435118931605545409","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:46 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"10.1.116.42","Source User Name":"Jessica Paola Guzman Cabrera (JGuzman)","Destination":"SRV_DC_01 (10.1.200.11)","Service":"PUERTO_3268 (TCP/3268)","Access Rule Number":"49","Access Rule Name":"Acceso Redes a DNS-DHCP","Policy Name":"Standard","Description":"PUERTO_3268 Traffic Accepted from Jessica Paola Guzman Cabrera (JGuzman)(10.1.116.42) to 'srv-dc-01@coopcrea.fin.ec'(10.1.200.11)","Id":"5b83a05e-a69f-e3fc-5ece-93ce0001000b","Marker":"@A@@B@1590555605@C@2969324","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Id Generated By Indexer":"false","First":"false","Sequencenum":"44","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"PUERTO_3268","Source Port":"64495","Destination Port":"3268","IP Protocol":"TCP (6)","Source Machine Name":"asis-gerencia@coopcrea.fin.ec","Hll Key":"10562086023940820115","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"17e4739f-71c5-448b-a698-c581fc82eaa5","Layer Name":"Network","User":"Jessica Paola Guzman Cabrera (JGuzman)","Src User Dn":"CN=Jessica Paola  Guzman Cabrera OU=Usuarios OU=Gerencia OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec","Reason":"Connection terminated before detection: Insufficient data passed. To learn more see sk113479.","Destination Machine Name":"srv-dc-01@coopcrea.fin.ec"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:46 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"ARE-CREA-CAJA01.coopcrea.fin.ec (10.6.111.61)","Source User Name":"Andrea Cristina Naula Gonzales (ANaula)","Destination":"SRV_Corefinanciero_https (192.168.0.34)","Service":"https (TCP/443)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"https Traffic Accepted from Andrea Cristina Naula Gonzales (ANaula)(10.6.111.61) to 'corefinanciero0@coopcrea.fin.ec'(192.168.0.34)","Id":"5b83a05e-a69f-e3fc-5ece-93ce00010034","Marker":"@A@@B@1590555605@C@2969317","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth2.1106","Id Generated By Indexer":"false","First":"false","Sequencenum":"37","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"https","Source Port":"49385","Destination Port":"443","IP Protocol":"TCP (6)","Source Machine Name":"are-crea-caja01@coopcrea.fin.ec","Hll Key":"665300296880089140","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","User":"Andrea Cristina Naula Gonzales (ANaula)","Src User Dn":"CN=Andrea Cristina Naula Gonzales OU=Usuarios OU=Cajas OU=Ag. Arenal OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec","Reason":"Connection terminated before detection: Insufficient data passed. To learn more see sk113479.","Destination Machine Name":"corefinanciero0@coopcrea.fin.ec","Destination User Name":"Christian Oswaldo Juca Cochancela (cjuca)","Dst User Dn":"CN=Christian Oswaldo Juca Cochancela OU=Usuarios OU=TICs OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"192.168.6.210","Destination":"192.168.0.115","Service":"domain-udp (UDP/53)","Access Rule Number":"75","Access Rule Name":"Entre Redes usuarios","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from 192.168.6.210 to 192.168.0.115","Id":"5b83a05e-a69f-e3fc-5ece-93d50001003c","Marker":"@A@@B@1590555605@C@2969295","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth2.1106","Connection Direction":"Internal","Id Generated By Indexer":"false","First":"true","Sequencenum":"140","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"domain-udp","Source Port":"55719","Destination Port":"53","IP Protocol":"UDP (17)","Hll Key":"15074758567040520074","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"98799291-e7c5-491f-90de-30ad2aa447fc","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"Srv_Corefinanciero01_Test (10.1.200.107)","Destination":"edge-star-shv-01-mia3.facebook.com (31.13.67.16)","Service":"https (TCP/443)","Access Rule Number":"59","Access Rule Name":"Salida servers","Policy Name":"Standard","Description":"https Traffic Accepted from 10.1.200.107 to 31.13.67.16","Id":"5b83a05e-a69f-e3fc-5ece-93d500010032","Marker":"@A@@B@1590555605@C@2969291","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"136","Source Zone":"Internal","Destination Zone":"External","Service ID":"https","Source Port":"51527","Destination Port":"443","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"IP_PUBLICA_TELCONET (190.95.243.6)","Xlate (NAT) Source Port":"54885","Xlate (NAT) Destination Port":"0","NAT Rule Number":"57","NAT Additional Rule Number":"0","Hll Key":"15318833474787327930","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"cbf08ce9-5d9e-440b-a29d-549366538058","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Reject","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"cjuca_TI (10.1.117.44)","Source User Name":"Christian Oswaldo Juca Cochancela (cjuca)","Destination":"1drv.ms (13.107.42.12)","Service":"https (TCP/443)","Access Rule Number":"26","Access Rule Name":"Bloque Varios Agencias","Policy Name":"Standard","Description":"https Traffic Rejected from Christian Oswaldo Juca Cochancela (cjuca)(10.1.117.44) to 13.107.42.12","Id":"5b83a05e-a69f-e3fc-5ece-93d50001002c","Marker":"@A@@B@1590555605@C@2969285","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"128","Source Zone":"Internal","Destination Zone":"External","Service ID":"cp_tcp_A936BBAC_EBC3_4F18_B3CC_A63365F07477","Source Port":"60470","Destination Port":"443","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"IP_PUBLICA_TELCONET (190.95.243.6)","Xlate (NAT) Source Port":"54884","Xlate (NAT) Destination Port":"0","NAT Rule Number":"253","NAT Additional Rule Number":"0","Source Machine Name":"lap-sop@coopcrea.fin.ec","Hll Key":"2395045077387778228","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"cda4a27d-4020-4530-ae1a-d85e8b51b1a4","Layer Name":"App Control & URL Filtering","Needs Browse Time":"1","User":"Christian Oswaldo Juca Cochancela (cjuca)","Src User Dn":"CN=Christian Oswaldo Juca Cochancela OU=Usuarios OU=TICs OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec","Protocol":"HTTPS","Sig Id":"13","UserCheck ID":"A361CEFA-26A7-F551-DAF5-33B7BFC4251E"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"10.10.115.31","Destination":"193.182.111.143","Service":"ntp-udp (UDP/123)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"ntp-udp Traffic Accepted from 10.10.115.31 to 193.182.111.143","Id":"5b83a05e-a69f-e3fc-5ece-93ad0001006c","Marker":"@A@@B@1590555605@C@2969284","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth2.2110","Id Generated By Indexer":"false","First":"false","Sequencenum":"126","Source Zone":"Internal","Destination Zone":"External","Service ID":"ntp-udp","Source Port":"40719","Destination Port":"123","IP Protocol":"UDP (17)","Hll Key":"1393992232742403336","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","Protocol":"NTP-UDP","Sig Id":"7","Reason":"Connection terminated before detection: Insufficient data passed. To learn more see sk113479."}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"pruebas_desarrollo (10.1.117.54)","Destination":"SRV_DC_01 (10.1.200.11)","Service":"domain-udp (UDP/53)","Access Rule Number":"49","Access Rule Name":"Acceso Redes a DNS-DHCP","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from 10.1.117.54 to 'srv-dc-01@coopcrea.fin.ec'(10.1.200.11)","Id":"5b83a05e-a69f-e3fc-5ece-93d500010031","Marker":"@A@@B@1590555605@C@2969282","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Connection Direction":"Internal","Id Generated By Indexer":"false","First":"true","Sequencenum":"124","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"domain-udp","Source Port":"49215","Destination Port":"53","IP Protocol":"UDP (17)","Hll Key":"10598082077424751144","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"17e4739f-71c5-448b-a698-c581fc82eaa5","Layer Name":"Network","Destination Machine Name":"srv-dc-01@coopcrea.fin.ec"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"ctumipamba_infraestructura (10.1.117.51)","Source User Name":"Christian Paul Tumipamba Diaz (ctumipamba)","Destination":"NVR_Batan (192.168.5.200)","Service":"TCP_8000 (TCP/8000)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"TCP_8000 Traffic Accepted from Christian Paul Tumipamba Diaz (ctumipamba)(10.1.117.51) to 192.168.5.200","Id":"5b83a05e-a69f-e3fc-5ece-93d500010029","Marker":"@A@@B@1590555605@C@2969275","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Id Generated By Indexer":"false","First":"true","Sequencenum":"87","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"TCP_8000","Source Port":"50083","Destination Port":"8000","IP Protocol":"TCP (6)","Source Machine Name":"lap-tics-coordi@coopcrea.fin.ec","Hll Key":"9695048215528940900","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","User":"Christian Paul Tumipamba Diaz (ctumipamba)","Src User Dn":"CN=Christian Paul Tumipamba Diaz OU=Usuarios OU=TICs OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"10.13.111.120","Source User Name":"Franklin Geovanny Morocho Morocho (FMorocho)","Destination":"corp-190-110-211-142.gye.puntonet.ec (190.110.211.142)","Service":"https (TCP/443)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"https Traffic Accepted from Franklin Geovanny Morocho Morocho (FMorocho)(10.13.111.120) to 190.110.211.142","Id":"5b83a05e-a69f-e3fc-5ece-93d500010025","Marker":"@A@@B@1590555605@C@2969273","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth2.1113","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"77","Source Zone":"Internal","Destination Zone":"External","Service ID":"https","Source Port":"51737","Destination Port":"443","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"36278","Xlate (NAT) Destination Port":"0","NAT Rule Number":"119","NAT Additional Rule Number":"0","Source Machine Name":"mon-aux-cob@coopcrea.fin.ec","Hll Key":"1323744167277032632","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","Needs Browse Time":"1","User":"Franklin Geovanny Morocho Morocho (FMorocho)","Src User Dn":"CN=Franklin Geovanny Morocho Morocho OU=Usuarios OU=Negocios OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec","Protocol":"HTTPS","Sig Id":"4"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"10.1.112.47","Destination":"40.91.76.238","Service":"https (TCP/443)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"https Traffic Accepted from  'lap-secre-conse@coopcrea.fin.ec'(10.1.112.47) to 40.91.76.238","Id":"5b83a05e-a69f-e3fc-5ece-93d400010075","Marker":"@A@@B@1590555605@C@2969261","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"61","Source Zone":"Internal","Destination Zone":"External","Service ID":"https","Source Port":"60132","Destination Port":"443","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"IP_PUBLICA_TELCONET (190.95.243.6)","Xlate (NAT) Source Port":"54880","Xlate (NAT) Destination Port":"0","NAT Rule Number":"257","NAT Additional Rule Number":"0","Source Machine Name":"lap-secre-conse@coopcrea.fin.ec","Hll Key":"8331438116297923225","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","Needs Browse Time":"1","Protocol":"HTTPS","Sig Id":"4"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Drop","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"172.16.69.10","Source User Name":"Maria Gabriela Carpio Carpio (MCarpio)","Destination":"ImpreRicoh401Ger (10.1.116.43)","Service":"snmp (UDP/161)","Access Rule Number":"34","Access Rule Name":"Bloqueo Contingencia CREA","Policy Name":"Standard","Description":"snmp Traffic Dropped from Maria Gabriela Carpio Carpio (MCarpio)(172.16.69.10) to 10.1.116.43","Id":"0a01c901-d031-6619-5ece-93d501a80000","Marker":"@A@@B@1590555605@C@2969256","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth3","Id Generated By Indexer":"false","First":"true","Sequencenum":"56","Source Zone":"External","Destination Zone":"Internal","Service ID":"snmp","Source Port":"49668","Destination Port":"161","IP Protocol":"UDP (17)","Source Machine Name":"ope-asist-01@coopcrea.fin.ec","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"ae314827-4e6b-48f0-aea0-7af964ae5e0e","Layer Name":"Network","User":"Maria Gabriela Carpio Carpio (MCarpio)","Src User Dn":"CN=Maria Gabriela Carpio Carpio OU=Usuarios OU=Operaciones OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"asextreme-des.coopcrea.fin.ec (10.1.200.243)","Destination":"192.168.0.108","Service":"StoneBeat-Daemon (TCP/3001)","Access Rule Number":"55","Access Rule Name":"Entre Redes Servers","Policy Name":"Standard","Description":"StoneBeat-Daemon Traffic Accepted from 10.1.200.243 to 192.168.0.108","Id":"5b83a05e-a69f-e3fc-5ece-93cd00010005","Marker":"@A@@B@1590555605@C@2969250","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Id Generated By Indexer":"false","First":"false","Sequencenum":"49","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"StoneBeat-Daemon","Source Port":"58555","Destination Port":"3001","IP Protocol":"TCP (6)","Hll Key":"8620952623645079834","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"2534539c-3941-417e-aaca-20b99295a5a3","Layer Name":"Network","Reason":"Connection terminated before detection: Insufficient data passed. To learn more see sk113479."}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:45 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"asextreme-des.coopcrea.fin.ec (10.1.200.243)","Destination":"192.168.0.108","Service":"StoneBeat-Daemon (TCP/3001)","Access Rule Number":"55","Access Rule Name":"Entre Redes Servers","Policy Name":"Standard","Description":"StoneBeat-Daemon Traffic Accepted from 10.1.200.243 to 192.168.0.108","Id":"5b83a05e-a69f-e3fc-5ece-93cd00010019","Marker":"@A@@B@1590555605@C@2969246","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Id Generated By Indexer":"false","First":"false","Sequencenum":"45","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"StoneBeat-Daemon","Source Port":"58559","Destination Port":"3001","IP Protocol":"TCP (6)","Hll Key":"8620952623645079834","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"2534539c-3941-417e-aaca-20b99295a5a3","Layer Name":"Network","Reason":"Connection terminated before detection: Insufficient data passed. To learn more see sk113479."}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:44 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"lurgiles_desarrollo (10.1.117.34)","Source User Name":"Lilia Magdalena Urgiles Ortiz (LUrgiles)","Destination":"52.113.194.132","Service":"https (TCP/443)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"https Traffic Accepted from Lilia Magdalena Urgiles Ortiz (LUrgiles)(10.1.117.34) to 52.113.194.132","Id":"5b83a05e-a69f-e3fc-5ece-93d400010044","Marker":"@A@@B@1590555605@C@2969197","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"117","Source Zone":"Internal","Destination Zone":"External","Service ID":"https","Source Port":"61638","Destination Port":"443","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"IP_PUBLICA_TELCONET (190.95.243.6)","Xlate (NAT) Source Port":"54874","Xlate (NAT) Destination Port":"0","NAT Rule Number":"49","NAT Additional Rule Number":"0","Source Machine Name":"tics-coord@coopcrea.fin.ec","Hll Key":"6604862468084175823","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","Needs Browse Time":"1","User":"Lilia Magdalena Urgiles Ortiz (LUrgiles)","Src User Dn":"CN=Lilia Magdalena Urgiles Ortiz OU=Usuarios OU=TICs OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec","Protocol":"HTTPS","Sig Id":"4"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:44 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_CONSOLA_ESET (10.1.200.13)","Destination":"um13.eset.com (38.90.226.40)","Service":"http (TCP/80)","Access Rule Number":"59","Access Rule Name":"Salida servers","Policy Name":"Standard","Description":"http Traffic Accepted from 10.1.200.13 to 38.90.226.40","Id":"5b83a05e-a69f-e3fc-5ece-93d400010028","Marker":"@A@@B@1590555605@C@2969196","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"115","Source Zone":"Internal","Destination Zone":"External","Service ID":"http","Source Port":"55076","Destination Port":"80","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"36271","Xlate (NAT) Destination Port":"0","NAT Rule Number":"57","NAT Additional Rule Number":"0","Hll Key":"17314492224383763975","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"cbf08ce9-5d9e-440b-a29d-549366538058","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:44 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_CONSOLA_ESET (10.1.200.13)","Destination":"h1-c01-b.eset.com (91.228.166.45)","Service":"http (TCP/80)","Access Rule Number":"59","Access Rule Name":"Salida servers","Policy Name":"Standard","Description":"http Traffic Accepted from 10.1.200.13 to 91.228.166.45","Id":"5b83a05e-a69f-e3fc-5ece-93d40001001a","Marker":"@A@@B@1590555605@C@2969192","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"94","Source Zone":"Internal","Destination Zone":"External","Service ID":"http","Source Port":"55075","Destination Port":"80","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"36270","Xlate (NAT) Destination Port":"0","NAT Rule Number":"57","NAT Additional Rule Number":"0","Hll Key":"15758660735555354153","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"cbf08ce9-5d9e-440b-a29d-549366538058","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:44 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"srv2.telconet.net (200.93.192.161)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 200.93.192.161","Id":"5b83a05e-a69f-e3fc-5ece-93d400010052","Marker":"@A@@B@1590555605@C@2969188","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"86","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"63962","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"55046","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"9435118931605545409","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:44 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"srv2.telconet.net (200.93.192.161)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 200.93.192.161","Id":"5b83a05e-a69f-e3fc-5ece-93d400010036","Marker":"@A@@B@1590555605@C@2969173","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"71","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"62366","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"54553","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"9435118931605545409","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:44 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"lurgiles_desarrollo (10.1.117.34)","Source User Name":"Lilia Magdalena Urgiles Ortiz (LUrgiles)","Destination":"52.109.2.16","Service":"https (TCP/443)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"https Traffic Accepted from Lilia Magdalena Urgiles Ortiz (LUrgiles)(10.1.117.34) to 52.109.2.16","Id":"5b83a05e-a69f-e3fc-5ece-93d30001005c","Marker":"@A@@B@1590555605@C@2969147","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"40","Source Zone":"Internal","Destination Zone":"External","Service ID":"https","Source Port":"61634","Destination Port":"443","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"IP_PUBLICA_TELCONET (190.95.243.6)","Xlate (NAT) Source Port":"54863","Xlate (NAT) Destination Port":"0","NAT Rule Number":"49","NAT Additional Rule Number":"0","Source Machine Name":"tics-coord@coopcrea.fin.ec","Hll Key":"6604862468084175823","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","Needs Browse Time":"1","User":"Lilia Magdalena Urgiles Ortiz (LUrgiles)","Src User Dn":"CN=Lilia Magdalena Urgiles Ortiz OU=Usuarios OU=TICs OU=Administrativos OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec","Protocol":"HTTPS","Sig Id":"4"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:44 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"ns1-201.azure-dns.com (40.90.4.201)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 40.90.4.201","Id":"5b83a05e-a69f-e3fc-5ece-93d300010064","Marker":"@A@@B@1590555605@C@2969118","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"1","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"64376","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"26324","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"8464178502456281894","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_03 (192.168.0.11)","Destination":"IP_DNS_Telconet (200.93.192.148)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-03@coopcrea.fin.ec'(192.168.0.11) to 200.93.192.148","Id":"5b83a05e-a69f-e3fc-5ece-93d300010058","Marker":"@A@@B@1590555605@C@2969107","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"128","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"61522","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"IP_PUBLICA_TELCONET (190.95.243.6)","Xlate (NAT) Source Port":"18160","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-03@coopcrea.fin.ec","Hll Key":"7415755334633645274","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"13.107.252.10","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 13.107.252.10","Id":"5b83a05e-a69f-e3fc-5ece-93d300010057","Marker":"@A@@B@1590555605@C@2969106","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"127","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"64034","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"44860","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"383396894467396295","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"srv2.telconet.net (200.93.192.161)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 200.93.192.161","Id":"5b83a05e-a69f-e3fc-5ece-93d300010048","Marker":"@A@@B@1590555605@C@2969094","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"110","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"63769","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"10538","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"9435118931605545409","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"VPN","Action":"Decrypt","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"172.16.69.9","Source User Name":"Jessica Paola Calle Avila (pcalle)","Destination":"SRV_DC_01 (10.1.200.11)","Service":"microsoft-ds (TCP/445)","Access Rule Number":"9","Access Rule Name":"Acceso VPNs Crea a ADs","Policy Name":"Standard","Description":"Decrypted in community RemoteAccess ","Id":"5b83a05e-a69f-e3fc-5ece-93d30001002f","Marker":"@A@@B@1590555605@C@2969069","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth3","Connection Direction":"Incoming","Id Generated By Indexer":"false","First":"true","Sequencenum":"69","Source Zone":"External","Destination Zone":"Internal","Service ID":"microsoft-ds","Source Port":"51453","Destination Port":"445","IP Protocol":"TCP (6)","Source Machine Name":"pc-contact02@coopcrea.fin.ec","Hll Key":"9657614779362882464","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"d881fdfd-67db-4f96-a386-063e5c82775a","Layer Name":"Network","User":"Jessica Paola Calle Avila (pcalle)","Src User Dn":"CN=Jessica Paola Calle Avila OU=Usuarios OU=CallCenter OU=Cuenca OU=CreaSync DC=coopcrea DC=fin DC=ec","Destination Machine Name":"srv-dc-01@coopcrea.fin.ec","Last Update Time71":"2020-05-27T16:22:43Z","Scheme":"IKE","Methods":"ESP: 3DES + SHA1","VPN Peer Gateway":"172.16.69.9","Community":"RemoteAccess","Mobile Access Session UID":"5ECE5ED4-0000-0000-0A01-C901811F0000","VPN Feature":"VPN"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"srv-clear_pass (10.1.200.31)","Destination":"SMS-GW-CHECK (10.1.200.1)","Service":"snmp (UDP/161)","Access Rule Number":"7","Access Rule Name":"Snmp FW","Policy Name":"Standard","Description":"snmp Traffic Accepted from 10.1.200.31 to 10.1.200.1","Id":"5b83a05e-a69f-e3fc-5ece-93d30001001f","Marker":"@A@@B@1590555605@C@2969061","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Id Generated By Indexer":"false","First":"true","Sequencenum":"59","Source Zone":"Internal","Destination Zone":"Local","Service ID":"snmp","Source Port":"59746","Destination Port":"161","IP Protocol":"UDP (17)","Hll Key":"16230095823163346090","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"e086441f-026f-4cbb-822a-a2f92acf47d7","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"10.1.112.47","Destination":"SRV_DC_01 (10.1.200.11)","Service":"domain-tcp (TCP/53)","Access Rule Number":"49","Access Rule Name":"Acceso Redes a DNS-DHCP","Policy Name":"Standard","Description":"domain-tcp Traffic Accepted from  'lap-secre-conse@coopcrea.fin.ec'(10.1.112.47) to 'srv-dc-01@coopcrea.fin.ec'(10.1.200.11)","Id":"5b83a05e-a69f-e3fc-5ece-93d300010011","Marker":"@A@@B@1590555605@C@2969058","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth0","Connection Direction":"Internal","Id Generated By Indexer":"false","First":"true","Sequencenum":"56","Source Zone":"Internal","Destination Zone":"Internal","Service ID":"domain-tcp","Source Port":"60128","Destination Port":"53","IP Protocol":"TCP (6)","Source Machine Name":"lap-secre-conse@coopcrea.fin.ec","Hll Key":"15501787783087108335","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"17e4739f-71c5-448b-a698-c581fc82eaa5","Layer Name":"Network","Destination Machine Name":"srv-dc-01@coopcrea.fin.ec"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"38.90.226.17","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 38.90.226.17","Id":"5b83a05e-a69f-e3fc-5ece-93d30001000c","Marker":"@A@@B@1590555605@C@2969054","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"52","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"62371","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"26021","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"3346998377526241104","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"srv2.telconet.net (200.93.192.161)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 200.93.192.161","Id":"5b83a05e-a69f-e3fc-5ece-93d30001000a","Marker":"@A@@B@1590555605@C@2969052","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"50","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"64333","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"10089","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"9435118931605545409","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
# {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"5/27/2020 11:22:43 AM","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"DEL-CAJA-01.coopcrea.fin.ec (10.11.111.61)","Source User Name":"Diana Elizabeth Calle Zeas (DCalle)","Destination":"a23-219-145-252.deploy.static.akamaitechnologies.com (23.219.145.252)","Service":"https (TCP/443)","Access Rule Number":"73","Access Rule Name":"Navegacion Todos","Policy Name":"Standard","Description":"https Traffic Accepted from Diana Elizabeth Calle Zeas (DCalle)(10.11.111.61) to 23.219.145.252","Id":"5b83a05e-a69f-e3fc-5ece-93ce00010030","Marker":"@A@@B@1590555605@C@2969034","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth2.2111","Id Generated By Indexer":"false","First":"false","Sequencenum":"19","Source Zone":"Internal","Destination Zone":"External","Service ID":"https","Source Port":"60919","Destination Port":"443","IP Protocol":"TCP (6)","Xlate (NAT) Source IP":"IP_PUBLICA_TELCONET (190.95.243.6)","Xlate (NAT) Source Port":"54814","Xlate (NAT) Destination Port":"0","NAT Rule Number":"83","NAT Additional Rule Number":"0","Source Machine Name":"del-caja-01@coopcrea.fin.ec","Hll Key":"17272865336343045937","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"7ccb7090-1dfc-445a-b5ad-eac35ad782f1","Layer Name":"Network","Needs Browse Time":"1","User":"Diana Elizabeth Calle Zeas (DCalle)","Src User Dn":"CN=Diana Elizabeth Calle Zeas OU=Usuarios OU=Cajas OU=Ag. Deleg OU=CreaSync DC=coopcrea DC=fin DC=ec"}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b6d474e668fd> in <module>
#      24         producer.flush()
#      25
# ---> 26     time.sleep(sleep)
#      27     c = c + 1
#      28     seed = seed + 1
#
# KeyboardInterrupt:

# %%
# Creamos productor de eventos Kafka
import json
ip_server = '192.168.1.101:9092'
kafka_topic = 'FW'
c = 0
sleep = 20
seed = 1
prediction_features = {"version":"1.0","time":"1616580513","id":"f0c48ba4-387d-11ea-a137-2e728ce88126","type":"FW","event":"DATA","data":{"Time":"1616580513","Blade":"Firewall","Action":"Accept","Type":"Connection","Origin":"SMS-GW-CHECK","Source":"SRV_DC_01 (10.1.200.11)","Destination":"srv2.telconet.net (200.93.192.161)","Service":"domain-udp (UDP/53)","Access Rule Number":"57","Access Rule Name":"Consulta DNS Domain Controllers","Policy Name":"Standard","Description":"domain-udp Traffic Accepted from  'srv-dc-01@coopcrea.fin.ec'(10.1.200.11) to 200.93.192.161","Id":"5b83a05e-a69f-e3fc-5ece-93d600010005","Marker":"@A@@B@1590555605@C@2969330","Log Server Origin":"SMS-GW-CHECK (10.1.201.1)","Interface Direction":"inbound","Interface Name":"eth1","Connection Direction":"Outgoing","Id Generated By Indexer":"false","First":"true","Sequencenum":"50","Source Zone":"Internal","Destination Zone":"External","Service ID":"domain-udp","Source Port":"64159","Destination Port":"53","IP Protocol":"UDP (17)","Xlate (NAT) Source IP":"SMS-GW-CHECK (179.49.29.10)","Xlate (NAT) Source Port":"54880","Xlate (NAT) Destination Port":"0","NAT Rule Number":"0","NAT Additional Rule Number":"0","Source Machine Name":"srv-dc-01@coopcrea.fin.ec","Hll Key":"9435118931605545409","Context Num":"1","Policy Management":"SMS-GW-CHECK","Db Tag":"{10B41B45-4E19-A745-9231-AE1687566AA9}","Policy Date":"Today  9:50:39","Product Family":"Access","Logid":"0","Policy Rule UID":"629deb9c-68ad-410e-87fa-e14059f0bd88","Layer Name":"Network"}}
#FUNCIONAL
json_object = json.dumps(prediction_features)   
row = json_object 
print((row))
producer.send(PREDICTION_TOPIC , row.encode())
producer.flush()

# %%
sc.stop()
